# %% [markdown]
# # Exploration
# Development playground

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 20, 10

import Quandl
from n472jw.secrets import quandl_api_key
from n472jw.metrics import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Utils

# %%
import os

#####[ PARAMS ]#####
date_start = pd.datetime(2010, 1, 1)
date_end = pd.datetime(2015, 12, 28)
all_tickers_csv = pd.read_csv('./data/WIKI-datasets-codes.csv', header=None)
all_tickers = list(all_tickers_csv[0].str.split('/').str.get(1))
exist_tickers = [x.split('.')[0] for x in os.listdir('./data/') if x.endswith('pkl')]
all_tickers = list(set(all_tickers).intersection(exist_tickers))
all_tickers.sort()
####################

import random
import pickle
def get_random_ticker():
    """returns ticker, 'data' for random ticker"""
    ticker = random.choice(all_tickers)
    data = pickle.load(open('./data/{}.pkl'.format(ticker), 'r'))
    data['Date'] = data.index
    data = data[['Date', 'Open', 'Close', 'Low', 'High']]
    return ticker, data

# %% [markdown]
# # Perform Evaluation:
#
# ### Add sophistication:
# - stop order below, percentage of stock size (limit losses)
# - evaluate in terms of amount made, not total
# - bound the size of the gap (relative to overall stock variance?)

# %% [markdown]
# # Moving Averages

# %%
from n472jw.metrics.moving_average_metrics import CrossingMovingAverages

ticker, data = get_random_ticker()
mametric = CrossingMovingAverages()
orders = mametric.transform(data)
orders.head()
# Out:
# /Users/jhack/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#         Date   buy_amt limit_date  stop_above  stop_below
# 0 2010-11-15  18.64795 2010-12-15         NaN         NaN
# 1 2012-02-13  16.13590 2012-03-14         NaN         NaN
# 2 2014-02-06  20.70245 2014-03-08         NaN         NaN
# 3 2014-11-10  22.22725 2014-12-10         NaN         NaN

# %% [markdown]
# # Down gaps

# %%
from n472jw.metrics.gap_metrics import DownGapMetric

ticker, data = get_random_ticker()
gap_metric = DownGapMetric()
orders = gap_metric.transform(data)
orders.head()
# Out:
#                  Date  buy_amt limit_date  stop_above  stop_below
# Date
# 2011-03-02 2011-03-02    12.02 2011-04-01       13.74     11.4190
# 2011-11-01 2011-11-01    10.71 2011-12-01       11.42     10.1745
# 2011-11-02 2011-11-02    10.23 2011-12-02       10.61      9.7185
# 2012-06-27 2012-06-27    10.30 2012-07-27       10.59      9.7850
# 2013-10-03 2013-10-03    10.05 2013-11-02       10.45      9.5475

# %% [markdown]
# # Analyst
#
# ### Evaluate DownGapMetric

# %%
from n472jw.stock_analyst import StockAnalyst

analyst = StockAnalyst()
metric = DownGapMetric()
ticker, data = get_random_ticker()

evaluation = analyst.evaluate(metric, data)
print ticker
evaluation.tail()
# Out:
# TDW
#                  Date  buy_amt limit_date  stop_above  stop_below    profit  \
# Date
# 2014-07-07 2014-07-07    51.80 2014-08-06     54.1300     49.2100 -0.050000
# 2014-11-28 2014-11-28    30.91 2014-12-28     35.2600     29.3645 -0.050000
# 2014-12-08 2014-12-08    29.12 2015-01-07     30.9800     27.6640  0.063874
# 2015-07-17 2015-07-17    19.73 2015-08-16     22.3000     18.7435 -0.050000
# 2015-12-02 2015-12-02     8.74 2016-01-01      9.2001      8.3030  0.052643
#
#             sell_date  sell_amt  index_profit
# Date
# 2014-07-07 2014-07-25   49.2100     -0.002963
# 2014-11-28 2014-12-08   29.3645     -0.006974
# 2014-12-08 2014-12-10   30.9800     -0.023472
# 2015-07-17 2015-07-22   18.7435     -0.005948
# 2015-12-02 2015-12-03    9.2001     -0.024785

# %% [markdown]
# ### Evaluate CrossingMovingAverages

# %%
analyst = StockAnalyst()
metric = CrossingMovingAverages()
ticker, data = get_random_ticker()

evaluation = analyst.evaluate(metric, data)
evaluation.head()
# Out:
#         Date   buy_amt limit_date  stop_above  stop_below    profit  \
# 0 1998-04-28  25.16405 1998-05-28         NaN         NaN  0.018119
# 1 2001-03-06  15.73895 2001-04-05         NaN         NaN -0.002475
# 2 2003-05-15  26.16560 2003-06-14         NaN         NaN  0.069343
# 3 2003-06-11  26.03040 2003-07-11         NaN         NaN  0.050310
# 4 2004-10-22  30.22600 2004-11-21         NaN         NaN  0.119235
#
#    sell_date  sell_amt  index_profit
# 0 1998-05-28     25.62      0.010179
# 1 2001-04-05     15.70     -0.072474
# 2 2003-06-16     27.98      0.076080
# 3 2003-07-11     27.34      0.013505
# 4 2004-11-22     33.83      0.063941

# %% [markdown]
# # Full-Scale Analysis
#
# #### Load All Stocks into Memory

# %%
# %%time
from tqdm import tqdm
stocks = {}
for ticker in tqdm(all_tickers):
    data = pd.read_pickle('./data/{}.pkl'.format(ticker)).loc[date_start:date_end]
    data['Date'] = data.index
    data = data[['Date', 'Open', 'Close', 'Low', 'High']]
    if len(data) > 0:
    stocks[ticker] = data
    
print 'Loaded {} stocks: '.format(len(stocks))
# Out:
# Loaded 3081 stocks:
# CPU times: user 1min 42s, sys: 2.94 s, total: 1min 45s
# Wall time: 3min 12s

# %% [markdown]
# #### Run CrossingMovingAverages

# %%
analyst = StockAnalyst()
metric = CrossingMovingAverages()

evals = {}
items = [(ticker, data) for ticker, data in stocks.iteritems()]
for ticker, data in tqdm(items):
    evaluation = analyst.evaluate(metric, data)
    evals[ticker] = evaluation
# Out:
#  43%|████▎     | 1314/3078 [02:22<03:26,  8.56it/s]

# %%
means = np.array([np.nanmean(x.profit) for x in evals.values()])
plt.hist(means, bins=np.linspace(-0.5, 0.5, 100))
plt.title('Avg. Performance of Stock Under Strategy X, Relative to S&P 500', fontsize=25)
plt.ylabel('# of Stocks', fontsize=20)
plt.xlabel('Avg. Return (1.0 = 100% return)', fontsize=20)

# %% [markdown]
# ## DownGapMetric

# %%
analyst = StockAnalyst()
metric = DownGapMetric()

evals = {}
items = [(ticker, data) for ticker, data in stocks.iteritems()]
for ticker, data in tqdm(items):
    evaluation = analyst.evaluate(metric, data)
    evals[ticker] = evaluation

# %%
means = np.array([np.nanmean(x.profit) for x in evals.values()])
plt.hist(means, bins=np.linspace(-0.5, 0.5, 100))
plt.title('Avg. Performance of Stock Under Strategy X, Relative to S&P 500', fontsize=25)
plt.ylabel('# of Stocks', fontsize=20)
plt.xlabel('Avg. Return (1.0 = 100% return)', fontsize=20)

# %% [markdown]
# # Results Verification
# Independently coded evaluation of wether an evaluation looks right

# %%
ticker, data = get_random_ticker()
analyst = StockAnalyst()
metric = CrossingMovingAverages()
preprocessed = metric.preprocess(data)
evaluation = analyst.evaluate(metric, data)

# %%
for ix, order in evaluation.iterrows():
    buy_date = order.Date
    sell_date = order.sell_date
    buy_amt = order.buy_amt
    sell_amt = order.sell_amt
    
    #=====[ Step 1: make sure buy and sell amounts are correct ]=====
    assert (buy_amt <= data.loc[buy_date].High) and (buy_amt >= data.loc[buy_date].Low)
    assert (sell_amt <= data.loc[sell_date].High) and (sell_amt >= data.loc[sell_date].Low)
    
    #=====[ Step 2: make sure profit is correctly calculated ]=====
    assert np.isclose((sell_amt - buy_amt) / buy_amt, order.profit)
    
    #=====[ Step 3: make sure that index profit is correctly calculated ]=====
    sp_index = analyst.sp_index
    index_period = sp_index[buy_date:sell_date]
    index_profit = (index_period.iloc[-1].Close - index_period.iloc[0].Open) / index_period.iloc[0].Open
    assert np.isclose(index_profit, order.index_profit)

# %% [markdown]
# # Metrics Visualization

# %%
gaps_metric = GapsGetFilled(up_threshold=0.3, down_threshold=0.3)
gaps_metric.ingest(data)
gaps_metric.plot()

# %%
mas_metric = CrossingMovingAverages(ma1=50, ma2=200)
mas_metric.plot(data)

# %% [markdown]
# # Metric Evaluation: Gaps Get Filled
# - Run the metric
# - find periods of a certain length afterwards...
# - each metric has it's own evaluation method though... should have a "buy at" and a "sell at"

# %%
#####[ PARAMS ]#####
metric = gaps_metric
hold_period = pd.Timedelta('60 days')
####################

#=====[ Step 1: get buy/sell dfs ]=====
buy_series, sell_series = metric.transform(data)

#=====[ Step 2: cut out periods afterwards ]=====
print '=====[ Buy Dates (down gap) ]====='
print 'Buy Date | Price Change over {}'.format(hold_period)
for date, val in buy_series.iterrows():
    df = data[date:date + pd.Timedelta('1 days') + hold_period]
    reaches_goal = df.High.max() >= val.down_gap_sell_price
    if reaches_goal:
        change = df.High.max() - df.iloc[0].Close 
    else:
        change = df.iloc[-1].Close - df.iloc[0].Close
    print date, reaches_goal, change

print 
    
print '=====[ Sell Dates (up gap) ]====='
print 'Sell Date | Price Change over {}'.format(hold_period)
for date, val in sell_series.iterrows():
    df = data[date:date + pd.Timedelta('1 days') + hold_period]
    reaches_goal = df.Low.min() <= val.up_gap_buy_price

    if reaches_goal:
        change = df.Low.min() - df.iloc[0].Open 
    else:
        change = df.iloc[-1].Close - df.iloc[0].Open
    print date, reaches_goal, change
# Out:
# =====[ Buy Dates (down gap) ]=====
# Buy Date | Price Change over 60 days 00:00:00
# 2013-02-05 00:00:00 False -12.78
# 2013-02-19 00:00:00 False -5.75
# 2013-04-05 00:00:00 True 17.09
# 2013-04-26 00:00:00 True 18.59
# 2013-06-24 00:00:00 True 53.23
# 2014-01-23 00:00:00 True 25.76
# 2014-08-28 00:00:00 True 17.6
# 2014-12-01 00:00:00 False -18.69
# 2015-02-12 00:00:00 True 15.73
# 2015-03-25 00:00:00 True 16.21
# 2015-04-06 00:00:00 True 20.35
# 2015-04-30 00:00:00 False -1.2
# 2015-05-05 00:00:00 True 19.48
# 2015-06-26 00:00:00 True 6.64
# 2015-07-06 00:00:00 True 20.97
# 2015-07-15 00:00:00 True 23.42
# 2015-07-27 00:00:00 False -63.305
# 2015-07-28 00:00:00 False -33.645
# 2015-08-03 00:00:00 True 9.92
# 2015-08-11 00:00:00 False -23.72
# 2015-08-12 00:00:00 True 7.69
# 2015-08-24 00:00:00 True 18.48
# 2015-09-18 00:00:00 True 62.25
# 2015-09-22 00:00:00 True 74.78
# 2015-11-13 00:00:00 True 24.02
# 2015-12-08 00:00:00 False -12.22
# 2015-12-11 00:00:00 True 7.62
# 2015-12-18 00:00:00 True 6.77
#
# =====[ Sell Dates (up gap) ]=====
# Sell Date | Price Change over 60 days 00:00:00
# 2013-01-10 00:00:00 True -18.13
# 2013-04-10 00:00:00 True -4.11
# 2013-07-16 00:00:00 False 35.39
# 2013-07-25 00:00:00 False 21.04
# 2013-08-22 00:00:00 True -5.23
# 2013-10-18 00:00:00 True -14.53
# 2014-01-08 00:00:00 True -31.34
# 2014-05-12 00:00:00 True -2.59
# 2014-07-21 00:00:00 False 30.78
# 2014-07-24 00:00:00 False 11.19
# 2014-07-25 00:00:00 False 0.79
# 2014-08-11 00:00:00 True -15.37
# 2014-10-21 00:00:00 True -2.56
# 2014-10-31 00:00:00 True -22.64
# 2014-12-18 00:00:00 True -28.99
# 2015-01-08 00:00:00 True -27.35
# 2015-02-10 00:00:00 True -18.08
# 2015-04-08 00:00:00 True -18.4
# 2015-04-09 00:00:00 True -26.8
# 2015-04-20 00:00:00 True -20.58
# 2015-04-27 00:00:00 True -30.0
# 2015-05-04 00:00:00 True -16.39
# 2015-06-17 00:00:00 True -51.1
# 2015-07-17 00:00:00 True -94.68
# 2015-07-30 00:00:00 True -72.5
# 2015-08-05 00:00:00 True -71.68
# 2015-08-27 00:00:00 True -16.48
# 2015-10-23 00:00:00 False 37.63
# 2015-10-26 00:00:00 False 24.46
# 2015-10-30 00:00:00 False 15.92

# %% [markdown]
# # Metric Evaluation: Crossing Moving Averages

# %%
#####[ PARAMS ]#####
metric = mas_metric
hold_period = pd.Timedelta('30 days')
####################

#=====[ Step 1: get buy/sell dfs ]=====
buy_series, sell_series = metric.transform(data)

#=====[ Step 2: cut out periods afterwards ]=====
print '=====[ Buy Dates (MA1 Crosses Over MA2)  ]====='
print 'Buy Date | Success | Price Change over {}'.format(hold_period)
for date, val in buy_series.iteritems():
    df = data[date:date + pd.Timedelta('1 days') + hold_period]
    change = df.iloc[-1].Close - df.iloc[0].Open
    success = change > 0
    print date, success, change

print '=====[ Sell Dates (MA1 Crossed Under MA2) ]====='
print 'Sell Date | Success | Price Change over {}'.format(hold_period)
for date, val in sell_series.iteritems():
    # TODO: check for end condition here #
    df = data[date:date + pd.Timedelta('1 days') + hold_period]
    change = df.iloc[-1].Close - df.iloc[0].Open
    success = change < 0
    print date, success, change
# Out:
# =====[ Buy Dates (MA1 Crosses Over MA2)  ]=====
# Buy Date | Success | Price Change over 30 days 00:00:00
# 2015-12-18 00:00:00 False -2.74
# =====[ Sell Dates (MA1 Crossed Under MA2) ]=====
# Sell Date | Success | Price Change over 30 days 00:00:00

# %% [markdown]
# # Old Utils

# %%
def rolling_apply(data, size, func):
    """multiple-column rolling window function as a generator"""
    n = len(data) - size + 1
    results = pd.DataFrame([func(data.iloc[i:i+size]) for i in range(n)])
    results.index = data.iloc[size-1:].index
    if len(results) == 0:
        results = pd.DataFrame(columns=['buy', 'stop', 'sell_by'])
    return results

def simulate(data, metric):
    #=====[ Step 1: get data and suggested results ]=====
    results = rolling_apply(data, metric.size, metric.ingest)
    data = pd.concat([data, results], axis=1)
    data['buy'] = data['buy'].fillna(False)
    
    #=====[ Step 2: evaluate ]=====
    profits = []
    for start_time, row in data[data.buy].iterrows():
        buy_price = row.Close
        end_time = row.sell_by
        hold_window = data[start_time:end_time]
        
        #####[ CASE: closed the gap ]#####
        if hold_window.High.max() > row.stop_above:
            sell_price = row.stop_above
            
        #####[ CASE: stop below ]#####
        elif hold_window.Low.min() < row.stop_below:
            sell_price = row.stop_below

        #####[ CASE: clock not run out yet ]#####
        elif end_time > data.index.max():
            sell_price = np.nan

        #####[ CASE: ran out the clock ]#####
        else:
            sell_price = data[:end_time].iloc[-1].Close

        profit = sell_price - buy_price
        profits.append({'date':start_time, 'profit':profit})
    profits = pd.DataFrame(profits)
    if len(profits) == 0:
        profits = pd.DataFrame(columns=['date', 'profit'])
    profits.index = profits.date
    return profits['profit']
