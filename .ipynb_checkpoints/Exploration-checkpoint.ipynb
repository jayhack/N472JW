# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 20, 10

import Quandl
from n472jw.secrets import quandl_api_key
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # I. Get Data

# %%
#####[ PARAMS ]#####
ticker = 'ACN'
date_start = pd.datetime(2013, 1, 1)
date_end = pd.datetime(2015, 12, 28)
####################

data = Quandl.get('WIKI/{}'.format(ticker))
data = data[date_start:date_end]
data.head()
# Out:
#              Open   High    Low  Close   Volume  Ex-Dividend  Split Ratio  \
# Date
# 2013-01-02  67.59  69.06  67.55  69.06  4040500            0            1
# 2013-01-03  68.76  69.36  68.59  68.81  3340700            0            1
# 2013-01-04  68.92  69.61  68.32  69.19  3145600            0            1
# 2013-01-07  68.58  68.94  68.35  68.89  2262800            0            1
# 2013-01-08  68.76  69.46  68.66  69.29  2502800            0            1
#
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2013-01-02  65.284463  66.704320  65.245827   66.704320      4040500
# 2013-01-03  66.414553  66.994087  66.250352   66.462848      3340700
# 2013-01-04  66.569095  67.235559  65.989562   66.829886      3145600
# 2013-01-07  66.240693  66.588413  66.018538   66.540119      2262800
# 2013-01-08  66.414553  67.090676  66.317964   66.926474      2502800

# %% [markdown]
# ## Heuristic: "Gaps get filled"
#
# ### Find Gaps

# %%
######[ PARAMS ]#####
up_thresh = 1
down_thresh = 1
#####################

#=====[ Step 1: reindex ]=====
df = data[['Low', 'High', 'Open', 'Close']].copy()
df['Date'] = df.index
df.index = range(len(df))

#=====[ Step 2: find gaps ]=====
lows = np.array(df.iloc[0:-1].Low)

down_gap_amounts = (np.array(df[0:-1].Low) - np.array(df[1:].High))
down_gaps = down_gap_amounts > 0
up_gap_amounts = (np.array(df[1:].Low) - np.array(df[0:-1].High))
up_gaps = up_gap_amounts > 0
up_gaps = (df[1:].Low > df[0:-1].High)

#=====[ Step 3: reintegrate into series ]=====
df['down_gap_amount'] = np.nan
df['down_gap_amount'].iloc[1:] = down_gap_amounts
df['down_gap'] = df.down_gap_amount > down_thresh

df['up_gap_amount'] = np.nan
df['up_gap_amount'].iloc[1:] = up_gap_amounts
df['up_gap'] = df.up_gap_amount > up_thresh

#=====[ Step 4: find occurrences ]=====
df.index = df['Date']
df = df.drop(['Date'], axis=1)
down_df = df[df.down_gap][['down_gap_amount']]
up_df = df[df.up_gap][['up_gap_amount']]

# %% [markdown]
# ### Plot Occurrences

# %%
df['Open'].plot(color='b', label='open price')
ax = plt.gca()

for ix, row in down_df.iterrows():
    ax.axvline(x=row.name, color='r', linestyle='--', label='down gap')

for ix, row in up_df.iterrows():
    ax.axvline(x=row.name, color='g', linestyle='--', label='up gap')

    
ax.legend(loc='lower right')
ax.set_title('Up and Down Gaps: {}'.format(ticker), fontsize=20)

# %% [markdown]
# ## Heuristic: 50 Crosses 200
#
# ### Find Occurrences

# %%
#=====[ Step 1: reindex ]=====
df = data[['Low', 'High', 'Open', 'Close']].copy()
df['Date'] = df.index

#=====[ Step 2: get MAs ]=====
ma_50 = pd.rolling_mean(df.Open, 50)
ma_200 = pd.rolling_mean(df.Open, 200)

#=====[ Step 3: find crossings ]====
diff = ma_50 - ma_200
up_crosses = pd.rolling_apply(diff, 2, lambda x: (x[0] < 0) & (x[-1] > 0))
up_crosses = up_crosses[up_crosses > 0]
down_crosses = pd.rolling_apply(diff, 2, lambda x: (x[0] > 0) & (x[-1] < 0))
down_crosses = down_crosses[down_crosses > 0]

# %%
# Out:
# Date
# 2014-09-02    1
# Name: Open, dtype: float64

# %% [markdown]
# ### Plot

# %%
df['Open'].plot(label='open price', color='b')
ma_50.plot(label='50 day MA', color='g', linestyle='-')
ma_200.plot(label='200 day MA', color='r', linestyle='-')
ax = plt.gca()

for ix, row in down_crosses.iteritems():
    ax.axvline(x=ix, color='r', linestyle='--', label='down cross')
    
for ix, row in up_crosses.iteritems():
    ax.axvline(x=ix, color='g', linestyle='--', label='up cross')

ax.legend(loc='lower right')
ax.set_title('50/200 MAs Crossing: {}'.format(ticker), fontsize=20)

# %% [markdown]
# # TODO:
# - Formulate these as "metrics"
# - Each one:
#     - can send a buy signal
#     - can provide a visualization
# - need a uniform evaluation metric: how long to buy afterwards?

# %%
class StockMetric(object):
    """
    Class: StockMetric
    ==================
    Abstract class that provides a stock metric;
    
    Usage:
    ------
    buy_df, sell_df = stock_metric.transform(data)
    (each is a list of feature values indexed by dates)
    """
    def __init__(self, *args, **kwargs):
        pass
        
    def transform(self):
        raise NotImplementedError("override this")

    def plot(self):
        raise NotImplementedError("override this")
    

class GapsGetFilled(StockMetric):
    """
    Metric: GapsGetFilled
    =====================
    - previous day high lower than next day low -> SELL (overbought) 
    - previous day low higher than next day high -> BUY (oversold)
    
    Args:
    -----
    - up_threshold: minimum size of gap on upside
    - down_treshold: minimum size of gap on downside
    """
    def __init__(self, up_threshold=1, down_threshold=1):
        self.__dict__.update(locals())
        
    def transform(self, data):
        #=====[ Step 1: reindex ]=====
        df = data[['Low', 'High', 'Open', 'Close']].copy()
        df['Date'] = df.index
        df.index = range(len(df))

        #=====[ Step 2: find gaps ]=====
        lows = np.array(df.iloc[0:-1].Low)

        down_gap_amounts = (np.array(df[0:-1].Low) - np.array(df[1:].High))
        down_gaps = down_gap_amounts > 0
        up_gap_amounts = (np.array(df[1:].Low) - np.array(df[0:-1].High))
        up_gaps = up_gap_amounts > 0
        up_gaps = (df[1:].Low > df[0:-1].High)

        #=====[ Step 3: reintegrate into series ]=====
        df['down_gap_amount'] = np.nan
        df['down_gap_amount'].iloc[1:] = down_gap_amounts
        df['down_gap'] = df.down_gap_amount > self.down_threshold

        df['up_gap_amount'] = np.nan
        df['up_gap_amount'].iloc[1:] = up_gap_amounts
        df['up_gap'] = df.up_gap_amount > self.up_threshold

        #=====[ Step 4: find occurrences ]=====
        df.index = df['Date']
        df = df.drop(['Date'], axis=1)
        down_df = df[df.down_gap]['down_gap_amount']
        up_df = df[df.up_gap]['up_gap_amount']
        return down_df, up_df
    
    def plot(self, data):
        """finds metrics, plots inline"""
        #=====[ Step 1: find metrics ]=====
        down_df, up_df = self.transform(data)

        #=====[ Step 2: plot metrics ]=====
        data['Open'].plot(color='b', label='open price')
        ax = plt.gca()
        for ix, row in down_df.iteritems():
            ax.axvline(x=ix, color='r', linestyle='--', label='down gap')
        for ix, row in up_df.iteritems():
            ax.axvline(x=ix, color='g', linestyle='--', label='up gap')

        #=====[ Step 3: legend and title ]=====
        ax.legend(loc='lower right')
        ax.set_title('Up and Down Gaps', fontsize=20)
        
        
class CrossingMovingAverages(StockMetric):
    """
    Metric: CrossingMovingAverages
    ==============================
    MA 1 crosses over MA 2 -> buy
    MA 1 crosses under MA 2 -> sell

    Args:
    -----
    - ma1: number of days over which to calculate MA1
    - ma2: number of days over which to calculate MA2
    """
    def __init__(self, ma1=50, ma2=200):
        self.__dict__.update(locals())
        
    def transform(self, data):
        #=====[ Step 1: reindex ]=====
        df = data[['Low', 'High', 'Open', 'Close']].copy()
        df['Date'] = df.index

        #=====[ Step 2: get MAs ]=====
        ma_50 = pd.rolling_mean(df.Open, self.ma1)
        ma_200 = pd.rolling_mean(df.Open, self.ma2)

        #=====[ Step 3: find crossings ]====
        diff = ma_50 - ma_200
        up_crosses = pd.rolling_apply(diff, 2, lambda x: (x[0] < 0) & (x[-1] > 0))
        up_crosses = up_crosses[up_crosses > 0]
        down_crosses = pd.rolling_apply(diff, 2, lambda x: (x[0] > 0) & (x[-1] < 0))
        down_crosses = down_crosses[down_crosses > 0]
        return up_crosses, down_crosses
    
    def plot(self, data):
        #=====[ Step 1: get metrics ]=====
        up_crosses, down_crosses = self.transform(data)
        
        #=====[ Step 2: plot MAs ]=====
        df['Open'].plot(label='open price', color='b')
        ma_50.plot(label='50 day MA', color='g', linestyle='-')
        ma_200.plot(label='200 day MA', color='r', linestyle='-')
        ax = plt.gca()
        
        #=====[ Step 3: plot crosses ]=====
        for ix, row in down_crosses.iteritems():
            ax.axvline(x=ix, color='r', linestyle='--', label='down cross')
        for ix, row in up_crosses.iteritems():
            ax.axvline(x=ix, color='g', linestyle='--', label='up cross')

        #=====[ Step 4: legend ]=====
        ax.legend(loc='lower right')
        ax.set_title('50/200 MAs Crossing'.format(ticker), fontsize=20)

# %%
metric1 = GapsGetFilled(up_threshold=1, down_threshold=1)
metric1.plot(data)

# %%
metric2 = CrossingMovingAverages(ma1=50, ma2=200)
metric2.plot(data)
